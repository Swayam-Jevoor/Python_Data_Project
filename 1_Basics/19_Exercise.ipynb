# %% [markdown]
# ## Exercise - Data Cleanup
#
# Cleanup list and datetime objects

# %%
data_science_jobs = [
  {'job_title': 'Data Scientist', 'job_skills': "['Python','SQL','Machine Learning']",'job_date': '2023-05-12'},
  {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python','TensorFlow','Deep Learning']",'job_date': '2023-06-18'},
  {'job_title': 'Data Analyst', 'job_skills': "['Excel','SQL','Power BI']",'job_date': '2023-07-02'},
  {'job_title': 'AI Researcher', 'job_skills': "['Python','PyTorch','NLP']",'job_date': '2023-08-11'},
  {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL','Tableau','Data Warehousing']",'job_date': '2023-09-25'},
  {'job_title': 'Computer Vision Engineer', 'job_skills': "['Python','OpenCV','Deep Learning']",'job_date': '2023-10-09'},
  {'job_title': 'Data Engineer', 'job_skills': "['Python','Spark','ETL']",'job_date': '2023-11-14'},
  {'job_title': 'Statistician', 'job_skills': "['R','Statistics','Data Visualization']",'job_date': '2023-12-01'},
  {'job_title': 'NLP Engineer', 'job_skills': "['Python','Transformers','Text Mining']",'job_date': '2024-01-15'},
  {'job_title': 'Analytics Consultant', 'job_skills': "['SQL','Excel','Data Modeling']",'job_date': '2024-02-20'},
]

# %% [markdown]
# ## datetime

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 3, 1, 3, 9, 4, 260294)

# %%
data_science_jobs[0]
# Out:
# {'job_title': 'Data Scientist',
#  'job_skills': "['Python','SQL',Machine Learning']",
#  'job_date': '2023-05-12'}

# %%
data_science_jobs[0]['job_date']
# Out:
# '2023-05-12'

# %%
type(data_science_jobs[0]['job_date'])
# Out:
# str

# %%
test_date = data_science_jobs[0]['job_date']

# %%
datetime.strptime(test_date, '%Y-%m-%d')
# Out:
# datetime.datetime(2023, 5, 12, 0, 0)

# %%
print(datetime.strptime(test_date, '%Y-%m-%d'))
# Out:
# 2023-05-12 00:00:00

# %%
for job in data_science_jobs:
  job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': "['Python','SQL',Machine Learning']",
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': "['Python','TensorFlow','Deep Learning']",
#   'job_date': datetime.datetime(2023, 6, 18, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': "['Excel','SQL','Power BI']",
#   'job_date': datetime.datetime(2023, 7, 2, 0, 0)},
#  {'job_title': 'AI Researcher',
#   'job_skills': "['Python','PyTorch','NLP']",
#   'job_date': datetime.datetime(2023, 8, 11, 0, 0)},
#  {'job_title': 'Business Intelligence Developer',
#   'job_skills': "['SQL','Tableau','Data Warehousing']",
#   'job_date': datetime.datetime(2023, 9, 25, 0, 0)},
#  {'job_title': 'Computer Vision Engineer',
#   'job_skills': "['Python','OpenCV','Deep Learning']",
#   'job_date': datetime.datetime(2023, 10, 9, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': "['Python','Spark','ETL']",
# ...

# %%
import ast

for job in data_science_jobs:
# job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')
  job['job_skills'] = ast.literal_eval(job['job_skills'])

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'SQL', 'Machine Learning'],
#   'job_date': '2023-05-12'},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Deep Learning'],
#   'job_date': '2023-06-18'},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['Excel', 'SQL', 'Power BI'],
#   'job_date': '2023-07-02'},
#  {'job_title': 'AI Researcher',
#   'job_skills': ['Python', 'PyTorch', 'NLP'],
#   'job_date': '2023-08-11'},
#  {'job_title': 'Business Intelligence Developer',
#   'job_skills': ['SQL', 'Tableau', 'Data Warehousing'],
#   'job_date': '2023-09-25'},
#  {'job_title': 'Computer Vision Engineer',
#   'job_skills': ['Python', 'OpenCV', 'Deep Learning'],
#   'job_date': '2023-10-09'},
#  {'job_title': 'Data Engineer',
#   'job_skills': ['Python', 'Spark', 'ETL'],
#   'job_date': '2023-11-14'},
#  {'job_title': 'Statistician',
#   'job_skills': ['R', 'Statistics', 'Data Visualization'],
#   'job_date': '2023-12-01'},
# ...
