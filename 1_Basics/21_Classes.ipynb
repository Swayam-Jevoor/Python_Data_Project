# %%
class ZoltarsList:
  def __init__(self):
    """Initialize an empty list."""
    self._items = []

  def add(self, item):
    """Add an item to the end if the list."""
    self._items.append(item)

  def __getitem__(self, index):
    """Retrieve an item by index."""
    return self._items[index]

  def __setitem__(self, index, value):
    """Set an item at a sepcific index."""
    self._items[index] = value

  def __repr__(self):
    """Return a string representation of the list."""
    return str(self._items)

  def __len__(self):
    """Return the length of the list."""
    return len(self._items)

# %%
my_list = ZoltarsList()

# %%
my_list
# Out:
# []

# %%
my_list.add("Data Nerd")

# %%
my_list
# Out:
# ['Data Nerd']

# %%
my_list.add("Finance Nerd")

# %%
my_list
# Out:
# ['Data Nerd', 'Finance Nerd']

# %%
len(my_list)
# Out:
# 2

# %%
class BaseSalary:
  def __init__(self, base_salary, bonus_rate = 0.1, symbol = "$"):   # Self is a positional argument
    self.base_salary = base_salary  # base_salary is a keyword argument
    self.bonus_rate = bonus_rate
    self.symbol = symbol

  def __repr__(self):
    return f'{self.symbol}{self.base_salary: ,.0f}'

# %%
# class BaseSalary:
#   def __init__(obj, base_salary, bonus_rate = 0.1, symbol = "$"):   # Self is a positional argument
#     obj.base_salary = base_salary  # base_salary is a keyword argument
#     obj.bonus_rate = bonus_rate
#     obj.symbol = symbol

# %%
BaseSalary(100000)
# Out:
# $ 100,000

# %%
salary = BaseSalary(100000)

salary.base_salary   # base_salary is an attribute not a method()
# Out:
# 100000

# %%
salary.symbol
# Out:
# '$'

# %%
salary
# Out:
# $ 100,000

# %%
value = 1000000

f'{value:,.0f}'
# Out:
# '1,000,000'

# %%
class BaseSalary:
  def __init__(self, base_salary, bonus_rate = 0.1, symbol = "$"):   # Self is a positional argument
    self.base_salary = base_salary  # base_salary is a keyword argument
    self.bonus_rate = bonus_rate
    self.symbol = symbol
    self.total_salary = base_salary * (1 + bonus_rate)
    self.bonus = self.total_salary - self.base_salary

  def __repr__(self):
    return f'{self.symbol}{self.base_salary:,.0f}'

  def calculate_salary(self):
    return f'{self.symbol}{self.total_salary:,.0f}'

  def calculate_bonus(self):
    return f'{self.symbol}{self.bonus:,.0f}'

# %%
salary = BaseSalary(100000)

salary
# Out:
# $100,000

# %%
salary.symbol
# Out:
# '$'

# %%
salary.calculate_salary()
# Out:
# '$110,000'

# %%
salary.calculate_bonus()
# Out:
# '$10,000'
