# %%
2 + 3.0
# Out:
# 5.0

# %%
"What's " + "Up" + "!"
# Out:
# "What's Up!"

# %%
"What's up? " * 10
# Out:
# "What's up? What's up? What's up? What's up? What's up? What's up? What's up? What's up? What's up? What's up? "

# %%
3.0 - 2
# Out:
# 1.0

# %%
"What's up" - "up"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-386/2152556247.py in <cell line: 0>()
# ----> 1 "What's up" - "up"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
four = 4

four.__sub__(2)
# Out:
# 2

# %%
4 - 2
# Out:
# 2

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
 print("5 divided by 2 is", 5 // 2, "with a remainder of", 5 % 2)
# Out:
# 5 divided by 2 is 2 with a remainder of 1

# %% [markdown]
# ## Order of Operations
# 1. **Parentheses**: Anything in parentheses is executed first.
# 2. **Exponents**: Operations involving exponents (including roots, indicated as fractional exponents).
# 3. **Multiplication and Division**: Processed from left to right.
# 4. **Addition and Subtraction**: Also processed from left to right.

# %%
min_salary = 20_000  # _ is ignored by the interpreter
max_salary = 80_000

avg_salary = (min_salary + max_salary) / 2

avg_salary
# Out:
# 50000.0

# %% [markdown]
# ## Assignment Operators

# %%
# Swapping names

applicant_1 = "Zoltar"
applicant_2 = "Strixxi"

# %%
temp_var = applicant_1

# %%
applicant_1 = applicant_2
applicant_2 = temp_var

# %%
applicant_1, applicant_2
# Out:
# ('Strixxi', 'Zoltar')

# %%
applicant_1, applicant_2 = applicant_2, applicant_1

# %%
applicant_1, applicant_2
# Out:
# ('Strixxi', 'Zoltar')

# %%
x = 1

# %%
x = x + 1

# %%
x
# Out:
# 2

# %%
x = 1

x += 1  # x = x + 1

# %%
x
# Out:
# 2

# %%
x = 1

x *= 2

# %%
x
# Out:
# 2

# %% [markdown]
# ## Comparison Operators

# %%
salary_zoltar = 60_000
salary_strixxi = 40_000

# %%
salary_zoltar == salary_strixxi
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
1 = 1
# Out:
#   File "/tmp/ipython-input-386/814398681.py", line 1
#     1 = 1
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
if(salary_zoltar > salary_strixxi):
  print("Zoltar is paid more than Strixxi")
# Out:
# Zoltar is paid more than Strixxi
