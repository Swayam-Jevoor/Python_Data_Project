# %%
if True:
  print("What's up Data Nerds")
# Out:
# What's up Data Nerds

# %%
if False:
  print("What's up Data Nerds")

# %%
# Skill required for job posting
job_skill = "SQL"

# Applicant skill
applicant_skill = "SQL"

# %%
if job_skill == applicant_skill:
  print("Skills Match!")
# Out:
# Skills Match!

# %%
job_skill = "SQL"
applicant_skill = "Python"
years_experience = 6

if job_skill == applicant_skill:
  print("Skills Match!")
elif years_experience >= 5:
  print("Enough Experience; No SQL")
# Out:
# Enough Experience; No SQL

# %%
job_skill = "SQL"
applicant_skill = "Python"
years_experience = 3

if job_skill == applicant_skill:
  print("Skills Match!")
elif years_experience >= 5:
  print("Enough Experience; No SQL")
else:
  print("No Skill or Experience")
# Out:
# No Skill or Experience

# %%
job_skill = "SQL"
applicant_skill = "Python"
years_experience = 3

if job_skill == applicant_skill:
  print("Skills Match!")
elif years_experience >= 5:
  print("Enough Experience; No SQL")
elif applicant_skill == "Python":
  print("This applicant should know SQL")
else:
  print("No Skill or Experience")
# Out:
# This applicant should know SQL

# %%
job_skill = "SQL"
applicant_skill = "Python"
years_experience = 3

if job_skill == applicant_skill:
  print("Skills Match!")
elif years_experience >= 5:
  print("Enough Experience; No SQL")
elif applicant_skill == "Python":
  pass
else:
  print("No Skill or Experience")

# %%
if job_skill == applicant_skill:
# Out:
#   File "/tmp/ipython-input-223/3891626849.py", line 1
#     if job_skill == applicant_skill:
#                                     ^
# SyntaxError: incomplete input

# %%
if job_skill == applicant_skill:
  pass

# %%
if job_skill == applicant_skill:
  ...
